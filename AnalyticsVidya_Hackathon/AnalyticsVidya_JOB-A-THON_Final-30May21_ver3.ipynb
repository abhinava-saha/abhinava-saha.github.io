# %% [markdown]
# **<center><span style="font-family: Arial; color:blue; font-size:2.4em; background-color:;">Analytics Vidya -</span></center>**
#
# **<center><span style="font-family: Arial; color:blue; font-size:2.0em; background-color:;">JOB-A-THON - May 2021</span></center>**
#
# <center><span style="font-family: verdana; color:blue; font-size:150%; background-color:yellow">Submitted By: Abhinava Kumar Saha</span></center>
#
# _<center><span style="color:black; font-size:120%; background-color:yellow">email: abhinava.saha@outlook.com | call: 8600068548</span></center>_
# <center><span style="color:black; font-size:100%">Date: May-30, 2021</span></center>

# %% [markdown]
# <p style="page-break-after:always;"></p>
# <div style="page-break-after: always;"></div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Problem-Statement---Credit-Card-Lead-Prediction" data-toc-modified-id="Problem-Statement---Credit-Card-Lead-Prediction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Problem Statement - Credit Card Lead Prediction</a></span><ul class="toc-item"><li><span><a href="#Load-the-given-survey-dataset-and-perform-basic-Exploratory-data-analysis." data-toc-modified-id="Load-the-given-survey-dataset-and-perform-basic-Exploratory-data-analysis.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Load the given survey dataset and perform basic Exploratory data analysis.</a></span><ul class="toc-item"><li><span><a href="#Load-the-given-Train-and-Test-dataset-and-check-the-data-header." data-toc-modified-id="Load-the-given-Train-and-Test-dataset-and-check-the-data-header.-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Load the given Train and Test dataset and check the data header.</a></span></li><li><span><a href="#Data-Dictionary." data-toc-modified-id="Data-Dictionary.-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Data Dictionary.</a></span></li><li><span><a href="#Check-the-shape-and-datatype-info-of-the-data." data-toc-modified-id="Check-the-shape-and-datatype-info-of-the-data.-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Check the shape and datatype info of the data.</a></span></li><li><span><a href="#Check-for-any-null-value-in-the-dataset." data-toc-modified-id="Check-for-any-null-value-in-the-dataset.-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Check for any null value in the dataset.</a></span></li><li><span><a href="#Check-for-duplicate-records-in-the-dataset." data-toc-modified-id="Check-for-duplicate-records-in-the-dataset.-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>Check for duplicate records in the dataset.</a></span></li><li><span><a href="#Drop-the-ID-column-from-the-datasets-and-check-Data-description." data-toc-modified-id="Drop-the-ID-column-from-the-datasets-and-check-Data-description.-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>Drop the ID column from the datasets and check Data description.</a></span></li></ul></li><li><span><a href="#Univariate-Analysis" data-toc-modified-id="Univariate-Analysis-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Univariate Analysis</a></span><ul class="toc-item"><li><span><a href="#Inspect-the-Categorical-data." data-toc-modified-id="Inspect-the-Categorical-data.-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Inspect the Categorical data.</a></span></li></ul></li><li><span><a href="#Analysis-of-Null-Values-[Credit_Product]-distribution-of-Target-variable." data-toc-modified-id="Analysis-of-Null-Values-[Credit_Product]-distribution-of-Target-variable.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Analysis of Null Values [Credit_Product] distribution of Target variable.</a></span></li><li><span><a href="#Label-Encode-all-Categorical-columns-to-numerical-columns." data-toc-modified-id="Label-Encode-all-Categorical-columns-to-numerical-columns.-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Label Encode all Categorical columns to numerical columns.</a></span></li><li><span><a href="#Bivariate-Analysis" data-toc-modified-id="Bivariate-Analysis-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Bivariate Analysis</a></span><ul class="toc-item"><li><span><a href="#Check-the-distribution-of-data-and-check-for-outliers." data-toc-modified-id="Check-the-distribution-of-data-and-check-for-outliers.-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Check the distribution of data and check for outliers.</a></span></li><li><span><a href="#Correlation-Heatmap." data-toc-modified-id="Correlation-Heatmap.-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Correlation Heatmap.</a></span></li><li><span><a href="#Pairplot." data-toc-modified-id="Pairplot.-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Pairplot.</a></span></li></ul></li><li><span><a href="#Save-the-datasets-with-all-numeric-features-into-file-for-future-use." data-toc-modified-id="Save-the-datasets-with-all-numeric-features-into-file-for-future-use.-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Save the datasets with all numeric features into file for future use.</a></span></li><li><span><a href="#Combine-Train-Test-and-do-Feature-Engineering." data-toc-modified-id="Combine-Train-Test-and-do-Feature-Engineering.-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Combine Train-Test and do Feature Engineering.</a></span></li><li><span><a href="#Log-Transform-the-Avg-Account-Balance-variable." data-toc-modified-id="Log-Transform-the-Avg-Account-Balance-variable.-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Log Transform the Avg Account Balance variable.</a></span></li><li><span><a href="#Clustering" data-toc-modified-id="Clustering-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Clustering</a></span><ul class="toc-item"><li><span><a href="#Generate-4-Clusters-using-K-Means-clustering-and-add-to-dataset." data-toc-modified-id="Generate-4-Clusters-using-K-Means-clustering-and-add-to-dataset.-1.9.1"><span class="toc-item-num">1.9.1&nbsp;&nbsp;</span>Generate 4 Clusters using K-Means clustering and add to dataset.</a></span></li><li><span><a href="#Create-Mean,-Max,-Min-of-Avg_Account_Balance-column-based-on-Channel-Code,-Occupation,-and/or-Age,-Region." data-toc-modified-id="Create-Mean,-Max,-Min-of-Avg_Account_Balance-column-based-on-Channel-Code,-Occupation,-and/or-Age,-Region.-1.9.2"><span class="toc-item-num">1.9.2&nbsp;&nbsp;</span>Create Mean, Max, Min of Avg_Account_Balance column based on Channel Code, Occupation, and/or Age, Region.</a></span></li><li><span><a href="#Split-into-Train-Test-and-write-the-datasets-with-new-features-to-files" data-toc-modified-id="Split-into-Train-Test-and-write-the-datasets-with-new-features-to-files-1.9.3"><span class="toc-item-num">1.9.3&nbsp;&nbsp;</span>Split into Train-Test and write the datasets with new features to files</a></span></li></ul></li><li><span><a href="#Train-Test-Split" data-toc-modified-id="Train-Test-Split-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Train-Test Split</a></span></li><li><span><a href="#Create-SMOTE-oversampled-dataset---Skipping-as-it-didn't-improve-Auc-score." data-toc-modified-id="Create-SMOTE-oversampled-dataset---Skipping-as-it-didn't-improve-Auc-score.-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>Create SMOTE oversampled dataset - Skipping as it didn't improve Auc score.</a></span></li><li><span><a href="#Create-a-Model-Performance-Log-file-to-capture-the-Model-performance-output." data-toc-modified-id="Create-a-Model-Performance-Log-file-to-capture-the-Model-performance-output.-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>Create a Model Performance Log file to capture the Model performance output.</a></span></li><li><span><a href="#Create-a-pipeline-of-base-models-and-use-Cross-validation-to-check-performance." data-toc-modified-id="Create-a-pipeline-of-base-models-and-use-Cross-validation-to-check-performance.-1.13"><span class="toc-item-num">1.13&nbsp;&nbsp;</span>Create a pipeline of base models and use Cross validation to check performance.</a></span><ul class="toc-item"><li><span><a href="#Model-performance-through-pipeline-Cross-validation-using-Original-data." data-toc-modified-id="Model-performance-through-pipeline-Cross-validation-using-Original-data.-1.13.1"><span class="toc-item-num">1.13.1&nbsp;&nbsp;</span>Model performance through pipeline Cross-validation using Original data.</a></span></li></ul></li><li><span><a href="#Light-GBM-Model" data-toc-modified-id="Light-GBM-Model-1.14"><span class="toc-item-num">1.14&nbsp;&nbsp;</span>Light-GBM Model</a></span></li><li><span><a href="#Drop-some-Not-useful-features" data-toc-modified-id="Drop-some-Not-useful-features-1.15"><span class="toc-item-num">1.15&nbsp;&nbsp;</span>Drop some Not useful features</a></span></li><li><span><a href="#LGBM-Model-with-Pipeline-Cross-validation" data-toc-modified-id="LGBM-Model-with-Pipeline-Cross-validation-1.16"><span class="toc-item-num">1.16&nbsp;&nbsp;</span>LGBM Model with Pipeline Cross validation</a></span></li><li><span><a href="#Generate-submission-file." data-toc-modified-id="Generate-submission-file.-1.17"><span class="toc-item-num">1.17&nbsp;&nbsp;</span>Generate submission file.</a></span><ul class="toc-item"><li><span><a href="#Fit-model-on-full-Train-data-and-generate-submission-file." data-toc-modified-id="Fit-model-on-full-Train-data-and-generate-submission-file.-1.17.1"><span class="toc-item-num">1.17.1&nbsp;&nbsp;</span>Fit model on full Train data and generate submission file.</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <p style="page-break-after:always;"></p>
# <div style="page-break-after: always;"></div>

# %% [markdown]
# # Problem Statement - Credit Card Lead Prediction
#
# Happy Customer Bank is a mid-sized private bank that deals in all kinds of banking products, like Savings accounts, Current accounts, investment products, credit products, among other offerings.
#
#
#
# The bank also cross-sells products to its existing customers and to do so they use different kinds of communication like tele-calling, e-mails, recommendations on net banking, mobile banking, etc.
#
#
#
# In this case, the Happy Customer Bank wants to cross sell its credit cards to its existing customers. The bank has identified a set of customers that are eligible for taking these credit cards.
#
#
#
# Now, the bank is looking for our help in identifying customers that could show higher intent towards a recommended credit card, given:
#
# - Customer details (gender, age, region etc.)
# - Details of his/her relationship with the bank (Channel_Code,Vintage, 'Avg_Asset_Value etc.)

# %% [markdown]
# ## Load the given survey dataset and perform basic Exploratory data analysis.

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns # for making plots with seaborn
color = sns.color_palette()
import sklearn.metrics as metrics
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve,\
                            classification_report, confusion_matrix, plot_confusion_matrix

import warnings
warnings.filterwarnings("ignore")
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'  # ‘all’|’last’|’last_expr’|’none’

# %% [markdown]
# ### Load the given Train and Test dataset and check the data header.

# %%
df_train = pd.read_csv('train_job_a_thon.csv')
df_test = pd.read_csv('test_job_a_thon.csv')
test_submission = df_test[['ID']]
y = df_train['Is_Lead']

# %%
df_train.head()
df_test.head()
test_submission.head()
# Out:
#          ID  Gender  Age Region_Code     Occupation Channel_Code  Vintage  \
# 0  NNVBBKZB  Female   73       RG268          Other           X3       43
# 1  IDD62UNG  Female   30       RG277       Salaried           X1       32
# 2  HD3DSEMC  Female   56       RG268  Self_Employed           X3       26
# 3  BF3NC7KV    Male   34       RG270       Salaried           X1       19
# 4  TEASRWXV  Female   30       RG282       Salaried           X1       33
#
#   Credit_Product  Avg_Account_Balance Is_Active  Is_Lead
# 0             No              1045696        No        0
# 1             No               581988        No        0
# 2             No              1484315       Yes        0
# 3             No               470454        No        0
# 4             No               886787        No        0
#          ID  Gender  Age Region_Code Occupation Channel_Code  Vintage  \
# 0  VBENBARO    Male   29       RG254      Other           X1       25
# 1  CCMEWNKY    Male   43       RG268      Other           X2       49
# 2  VK3KGA9M    Male   31       RG270   Salaried           X1       14
# 3  TT8RPZVC    Male   29       RG272      Other           X1       33
# 4  SHQZEYTZ  Female   29       RG270      Other           X1       19
#
#   Credit_Product  Avg_Account_Balance Is_Active
# 0            Yes               742366        No
# 1            NaN               925537        No
# 2             No               215949        No
# 3             No               868070        No
# 4             No               657087        No
#          ID
# 0  VBENBARO
# 1  CCMEWNKY
# 2  VK3KGA9M
# 3  TT8RPZVC
# 4  SHQZEYTZ

# %% [markdown]
# ### Data Dictionary.
#
# Check the data definition of each features in given dataset.

# %%
dd = [['ID',"Unique Identifier for a row"],
             ['Gender','Gender of the Customer'],
             ['Age','Age of the Customer (in Years)'],
             ['Region_Code','Code of the Region for the customers'],
             ['Occupation','Occupation Type for the customer'],
             ['Channel_Code','Acquisition Channel Code for the Customer  (Encoded)'],
             ['Vintage',"Vintage for the Customer (In Months)."],
             ['Credit_Product',"If the Customer has any active credit product (Home loan, Personal loan, Credit Card etc.)"],
             ['Avg_Account_Balance','Average Account Balance for the Customer in last 12 Months'],
             ['Is_Active','If the Customer is Active in last 3 Months'],
             ['Is_Lead(Target)','If the Customer is interested for the Credit Card:- \n\t\t\t  0 : Customer is not interested; 1 : Customer is interested']
            ]
dd = pd.DataFrame(dd,columns=['Attributes','Description'])

print("\033[1m\033[4m\033[43m     Variable Name:      \033[0m\
 \033[1m\033[4m\033[43m            Description:                   \033[0m")
for i in range(dd.shape[0]):
    print("\033[7m{:2}- {:20s}:\033[0m {}".format(
        str(i+1), dd.iloc[i, 0], dd.iloc[i, 1]))
# Out:
#      Variable Name:                   Description:
# 1 - ID                  : Unique Identifier for a row
# 2 - Gender              : Gender of the Customer
# 3 - Age                 : Age of the Customer (in Years)
# 4 - Region_Code         : Code of the Region for the customers
# 5 - Occupation          : Occupation Type for the customer
# 6 - Channel_Code        : Acquisition Channel Code for the Customer  (Encoded)
# 7 - Vintage             : Vintage for the Customer (In Months).
# 8 - Credit_Product      : If the Customer has any active credit product (Home loan, Personal loan, Credit Card etc.)
# 9 - Avg_Account_Balance : Average Account Balance for the Customer in last 12 Months
# 10- Is_Active           : If the Customer is Active in last 3 Months
# 11- Is_Lead(Target)     : If the Customer is interested for the Credit Card:-
# 			  0 : Customer is not interested; 1 : Customer is interested

# %% [markdown]
# ### Check the shape and datatype info of the data.

# %%
print ('\033[1mThe Train dataset has {}-rows and {}-columns.\033[0m'.format(df_train.shape[0], df_train.shape[1]))
print ('\033[1mThe Test dataset has {}-rows and {}-columns.\033[0m'.format(df_test.shape[0], df_test.shape[1]))
# Out:
# The Train dataset has 245725-rows and 11-columns.
# The Test dataset has 105312-rows and 10-columns.

# %%
print ('\n\033[7mTrain dataset Info.\033[0m\n')
df_train.info()

print ('\n\n\033[7mTest dataset Info.\033[0m\n')
df_test.info()
# Out:
# Train dataset Info.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245725 entries, 0 to 245724
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   245725 non-null  object
#  1   Gender               245725 non-null  object
#  2   Age                  245725 non-null  int64
#  3   Region_Code          245725 non-null  object
#  4   Occupation           245725 non-null  object
#  5   Channel_Code         245725 non-null  object
#  6   Vintage              245725 non-null  int64
#  7   Credit_Product       216400 non-null  object
#  8   Avg_Account_Balance  245725 non-null  int64
#  9   Is_Active            245725 non-null  object
#  10  Is_Lead              245725 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 20.6+ MB
#
#
# Test dataset Info.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105312 entries, 0 to 105311
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   105312 non-null  object
#  1   Gender               105312 non-null  object
#  2   Age                  105312 non-null  int64
#  3   Region_Code          105312 non-null  object
#  4   Occupation           105312 non-null  object
#  5   Channel_Code         105312 non-null  object
#  6   Vintage              105312 non-null  int64
#  7   Credit_Product       92790 non-null   object
#  8   Avg_Account_Balance  105312 non-null  int64
#  9   Is_Active            105312 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 8.0+ MB

# %% [markdown]
# - **Credit_Product column has null values in both Train and Test dataset.**
# - **Age, Vintage, Avg_Account_Balance and Is_Lead feature are integer type variable, which is as expected. All other variables are of object type.**

# %% [markdown]
# ### Check for any null value in the dataset.

# %%
print ('\n\033[7mCount of Null in Train dataset.\033[0m')
df_null = df_train.isna().sum().reset_index().rename(columns = {'index': 'Columns', 0: 'Count of Null'})
df_null['%age of Null'] = round(df_null['Count of Null'] *100 / df_train.shape[0], 2)
df_null

print ('\n\033[7mCount of Null in Test dataset.\033[0m')
df_null = df_test.isna().sum().reset_index().rename(columns = {'index': 'Columns', 0: 'Count of Null'})
df_null['%age of Null'] = round(df_null['Count of Null'] *100 / df_test.shape[0], 2)
df_null
# Out:
# Count of Null in Train dataset.
#                 Columns  Count of Null  %age of Null
# 0                    ID              0          0.00
# 1                Gender              0          0.00
# 2                   Age              0          0.00
# 3           Region_Code              0          0.00
# 4            Occupation              0          0.00
# 5          Channel_Code              0          0.00
# 6               Vintage              0          0.00
# 7        Credit_Product          29325         11.93
# 8   Avg_Account_Balance              0          0.00
# 9             Is_Active              0          0.00
# 10              Is_Lead              0          0.00
# Count of Null in Test dataset.
#                Columns  Count of Null  %age of Null
# 0                   ID              0          0.00
# 1               Gender              0          0.00
# 2                  Age              0          0.00
# 3          Region_Code              0          0.00
# 4           Occupation              0          0.00
# 5         Channel_Code              0          0.00
# 6              Vintage              0          0.00
# 7       Credit_Product          12522         11.89
# 8  Avg_Account_Balance              0          0.00
# 9            Is_Active              0          0.00

# %% [markdown]
# **We observe that in both Train and Test there are around 12% null values in Credit_Product variable.**

# %% [markdown]
# ### Check for duplicate records in the dataset.

# %%
dups = df_train.duplicated(keep='first')
print('\033[7mTotal count of duplicate records in Train dataset = {}.\033[0m'.format(dups.sum()))
df_train[dups]

dups = df_test.duplicated(keep='first')
print('\n\033[7mTotal count of duplicate records in Test dataset = {}.\033[0m'.format(dups.sum()))
df_test[dups]
# Out:
# Total count of duplicate records in Train dataset = 0.
# Empty DataFrame
# Columns: [ID, Gender, Age, Region_Code, Occupation, Channel_Code, Vintage, Credit_Product, Avg_Account_Balance, Is_Active, Is_Lead]
# Index: []
# Total count of duplicate records in Test dataset = 0.
# Empty DataFrame
# Columns: [ID, Gender, Age, Region_Code, Occupation, Channel_Code, Vintage, Credit_Product, Avg_Account_Balance, Is_Active]
# Index: []

# %% [markdown]
# - **We observe there are no duplicate records in the dataset, each record belong to unique person (ID).**

# %%
dups = df_train.drop(['ID','Is_Lead'],axis=1).duplicated(keep='first')
print('\033[7mTotal count of duplicate records (without ID columns) in Train dataset = {}.\033[0m'.format(dups.sum()))
df_train[dups]

dups = df_test.drop(['ID'],axis=1).duplicated(keep='first')
print('\n\033[7mTotal count of duplicate records (without ID columns) in Test dataset = {}.\033[0m'.format(dups.sum()))
df_test[dups]
# Out:
# Total count of duplicate records (without ID columns) in Train dataset = 23.
#               ID  Gender  Age Region_Code     Occupation Channel_Code  \
# 24155   WXXTY6IV  Female   39       RG270  Self_Employed           X1
# 50352   PSSK8RXK  Female   31       RG260       Salaried           X1
# 109811  QIHXODCJ  Female   28       RG254       Salaried           X1
# 113085  JTYRPQKQ    Male   44       RG281  Self_Employed           X2
# 122970  EFE2YP3R  Female   27       RG268       Salaried           X3
# 127357  NR8P3STS    Male   75       RG254          Other           X3
# 132289  K273RCCO    Male   25       RG275  Self_Employed           X1
# 133729  YNSECNTE  Female   29       RG257       Salaried           X1
# 139860  STAMP3SG    Male   26       RG281       Salaried           X1
# 168766  CW3UM6PS    Male   29       RG268       Salaried           X1
# 175857  VRWJIAME    Male   37       RG269  Self_Employed           X2
# 181419  RZMKVQV3    Male   32       RG268       Salaried           X1
# 185097  GTKZKZZR    Male   26       RG261       Salaried           X1
# 186003  TG7TUERX  Female   30       RG264       Salaried           X1
# 188789  9OHHRZJN    Male   28       RG261       Salaried           X1
# 192879  E78XHAFB  Female   25       RG281       Salaried           X1
# 204807  KKATAGM6  Female   26       RG268       Salaried           X1
# 206775  SSV3CRQP  Female   33       RG270       Salaried           X1
# 217385  Z4SXZUGJ    Male   32       RG284          Other           X2
# 219421  GYADWAQM    Male   26       RG269       Salaried           X1
# 220118  PBYJWNU2    Male   25       RG270       Salaried           X1
# 230013  HIS3KZAS    Male   26       RG275       Salaried           X1
# 241487  SPC2CGVH  Female   39       RG275  Self_Employed           X2
#
#         Vintage Credit_Product  Avg_Account_Balance Is_Active  Is_Lead
# 24155        32             No              1476563        No        0
# 50352        26             No              1435587        No        0
# 109811       26             No              1088995       Yes        0
# 113085       26            Yes              1501723        No        1
# 122970       20            Yes               739821        No        0
# 127357       75             No               930610       Yes        0
# 132289       13             No               564215        No        0
# 133729       26             No               799398        No        0
# 139860       14            Yes               944405        No        0
# 168766       13             No              1846545       Yes        0
# 175857       13            Yes               612640        No        0
# 181419       31             No              1266265        No        0
# 185097       15             No              1069877        No        0
# 186003       26             No               333500        No        0
# 188789       31             No              1075582        No        0
# 192879       13            Yes              1771180        No        0
# 204807       15             No              1908694       Yes        0
# 206775       31             No               485085        No        0
# 217385       33             No              3597985       Yes        0
# 219421       21             No               700207        No        0
# 220118       19             No               666788       Yes        0
# 230013       15            Yes               464188        No        0
# 241487       63             No               785371        No        0
# Total count of duplicate records (without ID columns) in Test dataset = 1.
#              ID Gender  Age Region_Code     Occupation Channel_Code  Vintage  \
# 90925  JTGWTPPI   Male   44       RG268  Self_Employed           X1       31
#
#       Credit_Product  Avg_Account_Balance Is_Active
# 90925             No              4260510        No

# %% [markdown]
# - **Without the ID column we can see there are 23 Train records which are duplicate. Which is possible as most of the feature except ID are generic and can be same for multiple people. Hence we will not remove any duplicate records in this case.**

# %% [markdown]
# ### Drop the ID column from the datasets and check Data description.

# %%
df_train.drop(['ID'],axis=1, inplace=True)
df_test.drop(['ID'],axis=1, inplace=True)

# %%
print ('\n\033[7mDescription of Train dataset.\033[0m')
for col in df_train.select_dtypes(include = 'object').columns:
    df_train[col] = df_train[col].astype('category')

df_train['Is_Lead'] = df_train['Is_Lead'].astype('category')
df_train.describe(exclude='number') 
df_train.describe()

print ('\n\033[7mDescription of Test dataset.\033[0m')
for col in df_test.select_dtypes(include = 'object').columns:
    df_test[col] = df_test[col].astype('category')

df_test.describe(exclude='number') 
df_test.describe()
# Out:
# Description of Train dataset.
#         Gender Region_Code     Occupation Channel_Code Credit_Product  \
# count   245725      245725         245725       245725         216400
# unique       2          35              4            4              2
# top       Male       RG268  Self_Employed           X1             No
# freq    134197       35934         100886       103718         144357
#
#        Is_Active  Is_Lead
# count     245725   245725
# unique         2        2
# top           No        0
# freq      150290   187437
#                  Age        Vintage  Avg_Account_Balance
# count  245725.000000  245725.000000         2.457250e+05
# mean       43.856307      46.959141         1.128403e+06
# std        14.828672      32.353136         8.529364e+05
# min        23.000000       7.000000         2.079000e+04
# 25%        30.000000      20.000000         6.043100e+05
# 50%        43.000000      32.000000         8.946010e+05
# 75%        54.000000      73.000000         1.366666e+06
# max        85.000000     135.000000         1.035201e+07
# Description of Test dataset.
#         Gender Region_Code     Occupation Channel_Code Credit_Product  \
# count   105312      105312         105312       105312          92790
# unique       2          35              4            4              2
# top       Male       RG268  Self_Employed           X1             No
# freq     57705       15125          43192        44484          61608
#
#        Is_Active
# count     105312
# unique         2
# top           No
# freq       63797
#                  Age        Vintage  Avg_Account_Balance
# count  105312.000000  105312.000000         1.053120e+05
# mean       43.871002      46.842819         1.134195e+06
# std        14.872890      32.273634         8.662430e+05
# min        24.000000       7.000000         2.259700e+04
# 25%        30.000000      20.000000         6.039822e+05
# 50%        43.000000      32.000000         8.966345e+05
# 75%        54.000000      73.000000         1.371598e+06
# max        85.000000     135.000000         9.908858e+06

# %% [markdown]
# ## Univariate Analysis
#
# ### Inspect the Categorical data.

# %%
InteractiveShell.ast_node_interactivity = 'last_expr'

# %%
for col in df_train.select_dtypes(include = 'category'):
    print(f"\n\033[7mVariable/attribute: {col.upper()} \033[0m\n")
    print(f"{col.title()} attribute has following unique values/levels:\n{df_train[col].unique()}\n")
    print(f"Count of data for each level of '{col}' attribute: \n{df_train[col].value_counts(1)}")
    
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    df_train[col].value_counts().plot(kind='pie')
    plt.subplot(1,2,2)
    df_train[col].value_counts().plot(kind='bar')
    plt.title(f'Countplot of {col} variable')
    plt.tight_layout()
    plt.show();
# Out:
# Variable/attribute: GENDER
#
# Gender attribute has following unique values/levels:
# [Female, Male]
# Categories (2, object): [Female, Male]
#
# Count of data for each level of 'Gender' attribute:
# Male      0.546127
# Female    0.453873
# Name: Gender, dtype: float64
# Variable/attribute: REGION_CODE
#
# Region_Code attribute has following unique values/levels:
# [RG268, RG277, RG270, RG282, RG261, ..., RG263, RG250, RG255, RG253, RG271]
# Length: 35
# Categories (35, object): [RG268, RG277, RG270, RG282, ..., RG250, RG255, RG253, RG271]
#
# Count of data for each level of 'Region_Code' attribute:
# RG268    0.146237
# RG283    0.119711
# RG254    0.109228
# RG284    0.078624
# RG277    0.052197
# RG280    0.051989
# RG269    0.031999
# RG270    0.031417
# RG261    0.031063
# RG257    0.024829
# RG251    0.024214
# RG282    0.023722
# RG274    0.021512
# RG272    0.021373
# RG281    0.020726
# RG273    0.018301
# RG252    0.017442
# RG279    0.016181
# RG263    0.015005
# RG275    0.013206
# RG260    0.012656
# RG256    0.011586
# RG264    0.011366
# RG276    0.011248
# RG259    0.010524
# RG250    0.010158
# RG255    0.008212
# RG258    0.007940
# RG253    0.007561
# RG278    0.007415
# RG262    0.007276
# RG266    0.006422
# RG265    0.006292
# RG271    0.006275
# RG267    0.006092
# Name: Region_Code, dtype: float64
# Variable/attribute: OCCUPATION
#
# Occupation attribute has following unique values/levels:
# [Other, Salaried, Self_Employed, Entrepreneur]
# Categories (4, object): [Other, Salaried, Self_Employed, Entrepreneur]
#
# Count of data for each level of 'Occupation' attribute:
# Self_Employed    0.410565
# Salaried         0.293006
# Other            0.285575
# Entrepreneur     0.010854
# Name: Occupation, dtype: float64
# Variable/attribute: CHANNEL_CODE
#
# Channel_Code attribute has following unique values/levels:
# [X3, X1, X2, X4]
# Categories (4, object): [X3, X1, X2, X4]
#
# Count of data for each level of 'Channel_Code' attribute:
# X1    0.422090
# X3    0.279630
# X2    0.275617
# X4    0.022664
# Name: Channel_Code, dtype: float64
# Variable/attribute: CREDIT_PRODUCT
#
# Credit_Product attribute has following unique values/levels:
# [No, NaN, Yes]
# Categories (2, object): [No, Yes]
#
# Count of data for each level of 'Credit_Product' attribute:
# No     0.667084
# Yes    0.332916
# Name: Credit_Product, dtype: float64
# Variable/attribute: IS_ACTIVE
#
# Is_Active attribute has following unique values/levels:
# [No, Yes]
# Categories (2, object): [No, Yes]
#
# Count of data for each level of 'Is_Active' attribute:
# No     0.611619
# Yes    0.388381
# Name: Is_Active, dtype: float64
# Variable/attribute: IS_LEAD
#
# Is_Lead attribute has following unique values/levels:
# [0, 1]
# Categories (2, int64): [0, 1]
#
# Count of data for each level of 'Is_Lead' attribute:
# 0    0.762792
# 1    0.237208
# Name: Is_Lead, dtype: float64

# %%
df_test.select_dtypes(include = 'category').head()
# Out:
#    Gender Region_Code Occupation Channel_Code Credit_Product Is_Active
# 0    Male       RG254      Other           X1            Yes        No
# 1    Male       RG268      Other           X2            NaN        No
# 2    Male       RG270   Salaried           X1             No        No
# 3    Male       RG272      Other           X1             No        No
# 4  Female       RG270      Other           X1             No        No

# %% [markdown]
# **Above features are non-numeric, we will need to convert them to numeric datatype.**
#
# **First we will convert these using lable encoding or ordinal encoding and check the model performance. Then we will gradually convert some of these as One-Hot encoding and see if there is improvement in performance.**
#
# - Gender will be converted as a binary data
# - For Occupation we will use label encoding.
# - For Channel Code we will use label encoding.
# - For Credit Product we will do a binary encoding
# - For Is Active we will do a binary encoding.
# - For Region Codes we will do a label encoding. Since this has too many levels doing one hot encoding will create too many features.
#
# **Later we will try doing One-hot coding for Occupation, Channel code.**

# %% [markdown]
# ## Analysis of Null Values [Credit_Product] distribution of Target variable.

# %%
InteractiveShell.ast_node_interactivity = 'all'

# %%
df_train[df_train['Credit_Product'] == 'Yes']['Is_Lead'].value_counts(1)
df_train[df_train['Credit_Product'] == 'No']['Is_Lead'].value_counts(1)
df_train[df_train['Credit_Product'].isnull()]['Is_Lead'].value_counts(1)
# Out:
# 0    0.685049
# 1    0.314951
# Name: Is_Lead, dtype: float64
# 0    0.926412
# 1    0.073588
# Name: Is_Lead, dtype: float64
# 1    0.851662
# 0    0.148338
# Name: Is_Lead, dtype: float64

# %%
plt.figure(figsize = (16,8))
sns.heatmap(df_train.isnull(), cbar = False, cmap = 'coolwarm', yticklabels = False)
plt.show()

# %% [markdown]
# **We can see that column Credit_Product has got null values**
# - We first imputed null with Mode and ROC_AUC score did not improve from 0.78. hence now we will impute Credit Product missing value as 1 and check results.
# - After imputing missing value of Credit Product as 1 Roc_Auc improved to 85%.
# - Since the distribution of Target column 'Is_Lead' is different(15%) compared to 31.5% for Yes and 7% for No, we will impute the null value as separate category and check performance which comes around 87%.

# %%
df_train['Credit_Product'].value_counts()
# Out:
# No     144357
# Yes     72043
# Name: Credit_Product, dtype: int64

# %%
#val = df_train['Credit_Product'].mode()[0]
#df_train['Credit_Product'] = df_train['Credit_Product'].fillna(value='Yes')
#df_test['Credit_Product'] = df_test['Credit_Product'].fillna(value='Yes')

# %% [markdown]
# ## Label Encode all Categorical columns to numerical columns.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cat_cols = ['Gender','Region_Code','Occupation','Channel_Code','Credit_Product','Is_Active']
for col in cat_cols:
    df_train[col] = le.fit_transform(df_train[col])
    df_test[col] = le.fit_transform(df_test[col])

# %%
df_train['Credit_Product'].value_counts()
# Out:
# 0    144357
# 1     72043
# 2     29325
# Name: Credit_Product, dtype: int64

# %%
InteractiveShell.ast_node_interactivity = 'all'

# %%
df_train.head()
df_test.head()
# Out:
#    Gender  Age  Region_Code  Occupation  Channel_Code  Vintage  \
# 0       0   73           18           1             2       43
# 1       0   30           27           2             0       32
# 2       0   56           18           3             2       26
# 3       1   34           20           2             0       19
# 4       0   30           32           2             0       33
#
#    Credit_Product  Avg_Account_Balance  Is_Active Is_Lead
# 0               0              1045696          0       0
# 1               0               581988          0       0
# 2               0              1484315          1       0
# 3               0               470454          0       0
# 4               0               886787          0       0
#    Gender  Age  Region_Code  Occupation  Channel_Code  Vintage  \
# 0       1   29            4           1             0       25
# 1       1   43           18           1             1       49
# 2       1   31           20           2             0       14
# 3       1   29           22           1             0       33
# 4       0   29           20           1             0       19
#
#    Credit_Product  Avg_Account_Balance  Is_Active
# 0               1               742366          0
# 1               2               925537          0
# 2               0               215949          0
# 3               0               868070          0
# 4               0               657087          0

# %% [markdown]
# **There are no null values in data now.**

# %% [markdown]
# ## Bivariate Analysis
#
# ### Check the distribution of data and check for outliers.

# %%
# The below function plots a histogram and corresponding boxplot for n variables at a time.
def plot_graph(l, u, df):
    i = 0
    cols = df.select_dtypes(include=[np.number]).columns

    if len(cols[l:u]) == 0:
        return -1
    else:
        j = len(cols[l:u])

    plt.figure(figsize=(5*j, 5))
    f, axs = plt.subplots(2, j, sharex='col',  figsize=(5*j, 5),
                          gridspec_kw={"height_ratios": (0.2, 1), 'wspace': (0.2), 'hspace': (0.00)})
    #(ax_box1,ax_box2,ax_box3), (ax_hist1,ax_hist2,ax_hist3) = axs

    for col in cols[l:u]:
        mean = df[col].mean()
        median = df[col].median()
        mode = df[col].mode()[0]

        if j == 1:
            ax_box = axs[0]
            ax_hist = axs[1]
        else:
            ax_box = axs[0, i]
            ax_hist = axs[1, i]

        sns.boxplot(df[col], ax=ax_box)
        ax_box.axvline(mean, color='r', linestyle='--')
        ax_box.axvline(median, color='g', linestyle='-')
        ax_box.axvline(mode, color='b', linestyle='-')
        ax_box.set_title(col, fontdict={'fontsize': 15, 'color': 'blue'})

        sns.distplot(df[col], ax=ax_hist)
        ax_hist.axvline(mean, color='r', linestyle='--')
        ax_hist.axvline(median, color='g', linestyle='-')
        ax_hist.axvline(mode, color='b', linestyle='-')
        #ax_hist.set_title(col, fontdict={'fontsize': 15, 'color': 'blue'})
        ax_hist.legend({'Mean': mean, 'Median': median, 'Mode': mode})
        i += 1
        ax_box.set(xlabel='')

#    plt.tight_layout()
    plt.show()


# Call the plot_graph function for n variables at a time.
def plot_hist_box(df, n):
    for i in range(0, 100, n):
        x = plot_graph(i, i+n, df)
        if x == -1:
            break

# %%
plot_hist_box(df_train, 3)

# %% [markdown]
# **Insights from above histograms.**
# - All the features are categorical in nature except the Avg_Account_Balance.
# - Avg Account Balance distribution is right skewed and has lot of outliers.
# - Also the scale of the data is in very high, which will cause problem for distance based algorithms like KNN, SVM etc. We can try using log transformation for this feature.

# %% [markdown]
# ### Correlation Heatmap.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_train.corr().round(2),annot=True);

# %% [markdown]
# **Insights from above Correlation heatmap.**
#
# - Age variable has very high correlation with Channel code and Vintage. Which would mean higher age group people have more longer relation with Bank. Also Channel code X4 seems to have more people of higher age group compared to X1.
#
# - Vintage and Channel code also has high correlation.
#
# - The target variable (Is_Lead) has got high correlation with Age, Channel code and Vintage. Which means older people having more relationship are more likely to be interested for Credit card.
#
# - Also people already having credit product is having slightly more chance of opting for credit card.

# %% [markdown]
# ### Pairplot.

# %%
sns.pairplot(df_train,hue='Is_Lead')

# %% [markdown]
# **Insights from the above pairplot.**
#
# - We see similar insights as observed above in correlation heatmat.
# - Higher age group people and Vintage customer are more interested for credit card.
# - People in channel code X2 and X3 are more interested in credit card.
# - People having higher average account balance is more likely to be interested in credit card.
# - Female are less likely to be interested in credit card.

# %% [markdown]
# ## Save the datasets with all numeric features into file for future use.

# %%
df_train.to_csv('train_all_numeric.csv',index=False)
df_test.to_csv('test_all_numeric.csv',index=False)
test_submission.to_csv('submission_file_backup.csv',index=False)

# %% [markdown]
# ## Combine Train-Test and do Feature Engineering.

# %%
# take backup of dataset
df_train_backup = df_train.copy()
df_test_backup = df_test.copy()
df_test_backup.head()
# Out:
#    Gender  Age  Region_Code  Occupation  Channel_Code  Vintage  \
# 0       1   29            4           1             0       25
# 1       1   43           18           1             1       49
# 2       1   31           20           2             0       14
# 3       1   29           22           1             0       33
# 4       0   29           20           1             0       19
#
#    Credit_Product  Avg_Account_Balance  Is_Active
# 0               1               742366          0
# 1               2               925537          0
# 2               0               215949          0
# 3               0               868070          0
# 4               0               657087          0

# %%
y = df_train['Is_Lead']
df_train = df_train.drop('Is_Lead', axis=1)
df_train['from_dataset'] = 'Train'
df_test['from_dataset'] = 'Test'

# %%
df = pd.concat([df_train, df_test])
df
# Out:
#         Gender  Age  Region_Code  Occupation  Channel_Code  Vintage  \
# 0            0   73           18           1             2       43
# 1            0   30           27           2             0       32
# 2            0   56           18           3             2       26
# 3            1   34           20           2             0       19
# 4            0   30           32           2             0       33
# ...        ...  ...          ...         ...           ...      ...
# 105307       1   52           18           2             1       86
# 105308       1   55           27           1             1       86
# 105309       1   35            4           2             3       15
# 105310       1   53            4           1             2       93
# 105311       1   27            6           2             0       21
#
#         Credit_Product  Avg_Account_Balance  Is_Active from_dataset
# 0                    0              1045696          0        Train
# 1                    0               581988          0        Train
# 2                    0              1484315          1        Train
# 3                    0               470454          0        Train
# 4                    0               886787          0        Train
# ...                ...                  ...        ...          ...
# 105307               1              4242558          1         Test
# 105308               1              1159153          0         Test
# 105309               0              1703727          0         Test
# 105310               0               737178          1         Test
# 105311               0               591565          0         Test
#
# [351037 rows x 10 columns]

# %% [markdown]
# ## Log Transform the Avg Account Balance variable.

# %%
InteractiveShell.ast_node_interactivity = 'last_expr'

# %%
plt.subplot(1, 2, 1)
(df['Avg_Account_Balance']).plot.hist(bins=50, figsize=(12, 6), edgecolor = 'white')
plt.xlabel('Avg_Account_Balance', fontsize=12)
plt.title('Avg_Account_Balance Distribution', fontsize=12)
plt.subplot(1, 2, 2)
np.log(df['Avg_Account_Balance']).plot.hist(bins=50, figsize=(12,6), edgecolor='white')
plt.xlabel('log(Avg_Account_Balance+1)', fontsize=12)
plt.title('Avg_Account_Balance Distribution', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Avg_Account_Balance Distribution')

# %%
df['Avg_Account_Balance'] = np.log(df['Avg_Account_Balance'])

# %% [markdown]
# ## Clustering

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
import scipy.cluster.hierarchy as shc
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_samples, silhouette_score
InteractiveShell.ast_node_interactivity = 'last_expr'

# %%
WSS = {}
for k in range(1,21):
    Kmeans = KMeans(n_clusters=k,random_state=1)
    Kmeans.fit(df.drop('from_dataset', axis=1))
    WSS[k] = Kmeans.inertia_
print("\033[1m\033[43mListed below are the Within Sum of Squares(WSS) value for 1 to 10 clusters:\033[0m")
WSS

#plt.plot(list(WSS.keys()), list(WSS.values()))
sns.pointplot(x = list(WSS.keys()), y = list(WSS.values()))
plt.xlabel('K Numbers')
plt.ylabel('WSS value (inertia)')
plt.title('Within Sum of Squares (WSS) plot')
plt.grid()
plt.show()
# Out:
# Listed below are the Within Sum of Squares(WSS) value for 1 to 10 clusters:

# %% [markdown]
# ### Generate 4 Clusters using K-Means clustering and add to dataset.

# %%
k_means = KMeans(n_clusters=40, random_state=1)
k_means.fit(df.drop('from_dataset', axis=1))
k_labels = k_means.labels_

df['Kcluster'] = k_labels

# %%
df['Kcluster'].value_counts()
df['Kcluster'].value_counts(1)
# Out:
# 28    0.075465
# 6     0.068178
# 32    0.062264
# 20    0.059752
# 16    0.056288
# 34    0.050391
# 5     0.030088
# 35    0.028225
# 4     0.027763
# 18    0.025373
# 7     0.024872
# 12    0.023884
# 10    0.023872
# 1     0.023009
# 22    0.022610
# 27    0.021847
# 17    0.021317
# 38    0.020397
# 21    0.020103
# 11    0.019764
# 13    0.019451
# 9     0.018611
# 33    0.018209
# 37    0.017548
# 0     0.017406
# 14    0.017232
# 3     0.016682
# 24    0.016645
# 29    0.016542
# 30    0.015543
# 25    0.014642
# 19    0.013987
# 8     0.013942
# 2     0.013437
# 26    0.011529
# 39    0.011452
# 31    0.011056
# 15    0.010711
# 23    0.010586
# 36    0.009330
# Name: Kcluster, dtype: float64

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='Kcluster', y='Avg_Account_Balance',data=df);
plt.figure(figsize=(12,5))
sns.countplot(x='Kcluster',data=df);

# %% [markdown]
# ### Create Mean, Max, Min of Avg_Account_Balance column based on Channel Code, Occupation, and/or Age, Region.

# %%
df.columns, df.shape
# Out:
# (Index(['Gender', 'Age', 'Region_Code', 'Occupation', 'Channel_Code', 'Vintage',
#         'Credit_Product', 'Avg_Account_Balance', 'Is_Active', 'from_dataset',
#         'Kcluster'],
#        dtype='object'),
#  (351037, 11))

# %%
# df_train["CC_Mean_Acc_Bal"] = df_train.groupby(['Channel_Code'])['Avg_Account_Balance'].transform('mean')
# Mean_Acc_Bal_dict = df_train.groupby(['Channel_Code'])['Avg_Account_Balance'].mean().to_dict()
# df_test['CC_Mean_Acc_Bal'] = df_test['Channel_Code'].apply(lambda x:Mean_Acc_Bal_dict.get(x,0))


df["Kcluster_Mean_Acc_Bal"] = df.groupby(['Kcluster'])['Avg_Account_Balance'].transform('mean')
df["Kcluster_Max_Acc_Bal"] = df.groupby(['Kcluster'])['Avg_Account_Balance'].transform('max')

df["Age_Mean_Acc_Bal"] = df.groupby(['Age'])['Avg_Account_Balance'].transform('mean')
df["Age_Max_Acc_Bal"] = df.groupby(['Age'])['Avg_Account_Balance'].transform('max')

df["Vin_Mean_Acc_Bal"] = df.groupby(['Vintage'])['Avg_Account_Balance'].transform('mean')
df["Vin_Max_Acc_Bal"] = df.groupby(['Vintage'])['Avg_Account_Balance'].transform('max')

df["KClus_RC_Mean_Acc_Bal"] = df.groupby(['Kcluster','Region_Code'])['Avg_Account_Balance'].transform('mean')
df["KClus_RC_Max_Acc_Bal"] = df.groupby(['Kcluster','Region_Code'])['Avg_Account_Balance'].transform('max')

df["KClus_Occ_Mean_Acc_Bal"] = df.groupby(['Kcluster','Occupation'])['Avg_Account_Balance'].transform('mean')
df["KClus_Occ_Max_Acc_Bal"] = df.groupby(['Kcluster','Occupation'])['Avg_Account_Balance'].transform('max')

df["KClus_CC_Mean_Acc_Bal"] = df.groupby(['Kcluster','Channel_Code'])['Avg_Account_Balance'].transform('mean')
df["KClus_CC_Max_Acc_Bal"] = df.groupby(['Kcluster','Channel_Code'])['Avg_Account_Balance'].transform('max')


df["All_Vin_Mean_Acc_Bal"] = df.groupby(['Kcluster','Gender', 'Region_Code', 'Occupation', 'Channel_Code', 'Vintage', 'Credit_Product', 'Is_Active']
                                   )['Avg_Account_Balance'].transform('mean')
df["All_Vin_Max_Acc_Bal"] = df.groupby(['Kcluster','Gender', 'Region_Code', 'Occupation', 'Channel_Code', 'Vintage', 'Credit_Product', 'Is_Active']
                                  )['Avg_Account_Balance'].transform('max')

df["All_Age_Mean_Acc_Bal"] = df.groupby(['Kcluster','Gender', 'Region_Code', 'Occupation', 'Channel_Code', 'Age', 'Credit_Product', 'Is_Active']
                                   )['Avg_Account_Balance'].transform('mean')
df["All_Age_Max_Acc_Bal"] = df.groupby(['Kcluster','Gender', 'Region_Code', 'Occupation', 'Channel_Code', 'Age', 'Credit_Product', 'Is_Active']
                                  )['Avg_Account_Balance'].transform('max')

df["All-Reg_Vin_Mean_Acc_Bal"] = df.groupby(['Kcluster','Gender', 'Occupation', 'Channel_Code', 'Vintage', 'Credit_Product', 'Is_Active']
                                   )['Avg_Account_Balance'].transform('mean')
df["All-Reg_Vin_Max_Acc_Bal"] = df.groupby(['Kcluster','Gender', 'Occupation', 'Channel_Code', 'Vintage', 'Credit_Product', 'Is_Active']
                                  )['Avg_Account_Balance'].transform('max')

df["All-Reg_Age_Mean_Acc_Bal"] = df.groupby(['Kcluster','Gender', 'Occupation', 'Channel_Code', 'Age', 'Credit_Product', 'Is_Active']
                                   )['Avg_Account_Balance'].transform('mean')
df["All-Reg_Age_Max_Acc_Bal"] = df.groupby(['Kcluster', 'Gender', 'Occupation', 'Channel_Code', 'Age', 'Credit_Product', 'Is_Active']
                                  )['Avg_Account_Balance'].transform('max')

df["Gen-Occ-Ch-CP-Act_Mean_Acc_Bal"] = df.groupby(['Kcluster','Gender', 'Occupation', 'Channel_Code', 'Credit_Product', 'Is_Active']
                                   )['Avg_Account_Balance'].transform('mean')
df["Gen-Occ-Ch-CP-Act_Max_Acc_Bal"] = df.groupby(['Kcluster','Gender',  'Occupation', 'Channel_Code', 'Credit_Product', 'Is_Active']
                                  )['Avg_Account_Balance'].transform('max')

df.head()
# Out:
#    Gender  Age  Region_Code  Occupation  Channel_Code  Vintage  \
# 0       0   73           18           1             2       43
# 1       0   30           27           2             0       32
# 2       0   56           18           3             2       26
# 3       1   34           20           2             0       19
# 4       0   30           32           2             0       33
#
#    Credit_Product  Avg_Account_Balance  Is_Active from_dataset  ...  \
# 0               0            13.860193          0        Train  ...
# 1               0            13.274205          0        Train  ...
# 2               0            14.210464          1        Train  ...
# 3               0            13.061453          0        Train  ...
# 4               0            13.695360          0        Train  ...
#
#    All_Vin_Mean_Acc_Bal  All_Vin_Max_Acc_Bal  All_Age_Mean_Acc_Bal  \
# 0             13.860193            13.860193             14.043627
# 1             13.476343            15.029933             13.567265
# 2             14.210464            14.210464             14.438664
# 3             13.232258            14.513394             13.239825
# 4             13.580622            14.991054             13.649506
#
#    All_Age_Max_Acc_Bal  All-Reg_Vin_Mean_Acc_Bal  All-Reg_Vin_Max_Acc_Bal  \
# 0            14.892420                 13.671340                14.555509
# 1            15.379942                 13.640934                15.957762
# 2            14.666865                 14.210464                14.210464
# 3            14.460763                 13.554804                15.716717
# 4            14.912592                 13.685082                16.002864
#
#    All-Reg_Age_Mean_Acc_Bal  All-Reg_Age_Max_Acc_Bal  \
# 0                 13.986326                15.117223
# 1                 13.650102                15.803773
# 2                 13.968804                15.208201
# 3                 13.496126                15.716717
# 4                 13.650102                15.803773
#
#    Gen-Occ-Ch-CP-Act_Mean_Acc_Bal  Gen-Occ-Ch-CP-Act_Max_Acc_Bal
# 0                       13.916590                      15.762839
# 1                       13.640382                      16.002864
# 2                       13.871167                      15.314601
# 3                       13.567591                      16.024404
# 4                       13.640382                      16.002864
#
# [5 rows x 33 columns]

# %%
# df_train["CC_Mean_Acc_Bal"] = df_train.groupby(['Channel_Code'])['Avg_Account_Balance'].transform('mean')
# Mean_Acc_Bal_dict = df_train.groupby(['Channel_Code'])['Avg_Account_Balance'].mean().to_dict()
# df_test['CC_Mean_Acc_Bal'] = df_test['Channel_Code'].apply(lambda x:Mean_Acc_Bal_dict.get(x,0))

df["Kcluster_Mean_Acc_Bal"] = df.groupby(['Kcluster'])['Avg_Account_Balance'].transform('mean')
df["Kcluster_Median_Acc_Bal"] = df.groupby(['Kcluster'])['Avg_Account_Balance'].transform('mean')
df["Kcluster_Max_Acc_Bal"] = df.groupby(['Kcluster'])['Avg_Account_Balance'].transform('max')

df["Age_Mean_Acc_Bal"] = df.groupby(['Age'])['Avg_Account_Balance'].transform('mean')
df["Age_Max_Acc_Bal"] = df.groupby(['Age'])['Avg_Account_Balance'].transform('max')

df["Vin_Mean_Acc_Bal"] = df.groupby(['Vintage'])['Avg_Account_Balance'].transform('mean')
df["Vin_Max_Acc_Bal"] = df.groupby(['Vintage'])['Avg_Account_Balance'].transform('max')

#df["All_Vin_Mean_Acc_Bal"] = df.groupby(['Gender', 'Region_Code', 'Occupation', 'Channel_Code', 'Vintage', 'Credit_Product', 'Is_Active']
#                                   )['Avg_Account_Balance'].transform('mean')
df["All_Vin_Max_Acc_Bal"] = df.groupby(['Gender', 'Region_Code', 'Occupation', 'Channel_Code', 'Vintage', 'Credit_Product', 'Is_Active']
                                  )['Avg_Account_Balance'].transform('max')

#df["All_Age_Mean_Acc_Bal"] = df.groupby(['Gender', 'Region_Code', 'Occupation', 'Channel_Code', 'Age', 'Credit_Product', 'Is_Active']
#                                   )['Avg_Account_Balance'].transform('mean')
df["All_Age_Max_Acc_Bal"] = df.groupby(['Gender', 'Region_Code', 'Occupation', 'Channel_Code', 'Age', 'Credit_Product', 'Is_Active']
                                  )['Avg_Account_Balance'].transform('max')

#df["All-Reg_Vin_Mean_Acc_Bal"] = df.groupby(['Gender', 'Occupation', 'Channel_Code', 'Vintage', 'Credit_Product', 'Is_Active']
#                                   )['Avg_Account_Balance'].transform('mean')
df["All-Reg_Vin_Max_Acc_Bal"] = df.groupby(['Gender', 'Occupation', 'Channel_Code', 'Vintage', 'Credit_Product', 'Is_Active']
                                  )['Avg_Account_Balance'].transform('max')

#df["All-Reg_Age_Mean_Acc_Bal"] = df.groupby(['Gender', 'Occupation', 'Channel_Code', 'Age', 'Credit_Product', 'Is_Active']
#                                   )['Avg_Account_Balance'].transform('mean')
#df["All-Reg_Age_Max_Acc_Bal"] = df.groupby(['Gender',  'Occupation', 'Channel_Code', 'Age', 'Credit_Product', 'Is_Active']
#                                  )['Avg_Account_Balance'].transform('max')


df.head()
# Out:
#    Gender  Age  Region_Code  Occupation  Channel_Code  Vintage  \
# 0       0   73           18           1             2       43
# 1       0   30           27           2             0       32
# 2       0   56           18           3             2       26
# 3       1   34           20           2             0       19
# 4       0   30           32           2             0       33
#
#    Credit_Product  Avg_Account_Balance  Is_Active from_dataset  Kcluster  \
# 0               0            13.860193          0        Train         4
# 1               0            13.274205          0        Train         0
# 2               0            14.210464          1        Train         2
# 3               0            13.061453          0        Train         0
# 4               0            13.695360          0        Train         4
#
#    Age_Mean_Acc_Bal  Age_Max_Acc_Bal  Vin_Mean_Acc_Bal  Vin_Max_Acc_Bal  \
# 0         13.945319        16.104640         13.844130        15.866973
# 1         13.630609        16.078823         13.643403        16.022784
# 2         13.846470        16.020495         13.642777        16.087755
# 3         13.601852        16.040465         13.620950        16.046349
# 4         13.630609        16.078823         13.650596        16.068270
#
#    All_Vin_Max_Acc_Bal  All_Age_Max_Acc_Bal  All-Reg_Vin_Max_Acc_Bal
# 0            14.704695            14.934041                14.721683
# 1            15.029933            15.379942                15.957762
# 2            14.709293            15.285756                14.882307
# 3            14.513394            15.112086                16.012359
# 4            14.991054            14.912592                16.027051

# %%
plot_hist_box(df, 4)

# %% [markdown]
# ### Split into Train-Test and write the datasets with new features to files

# %%
df.to_csv('DF_Combine_train_test_new_features1.csv',index=False)

# %%
df_train = df[df['from_dataset'] == 'Train']
df_test = df[df['from_dataset'] == 'Test']
df_train['Is_Lead'] = y

# %%
df_train.drop('from_dataset',axis=1,inplace=True)
df_test.drop('from_dataset',axis=1,inplace=True)

# %%
df_train.shape, df_test.shape
df_train.head()
df_test.head()
# Out:
#    Gender  Age  Region_Code  Occupation  Channel_Code  Vintage  \
# 0       1   29            4           1             0       25
# 1       1   43           18           1             1       49
# 2       1   31           20           2             0       14
# 3       1   29           22           1             0       33
# 4       0   29           20           1             0       19
#
#    Credit_Product  Avg_Account_Balance  Is_Active  Kcluster  ...  \
# 0               1            13.517598          0        28  ...
# 1               2            13.738129          0        38  ...
# 2               0            12.282798          0        32  ...
# 3               0            13.674028          0        16  ...
# 4               0            13.395572          0        32  ...
#
#    All_Vin_Mean_Acc_Bal  All_Vin_Max_Acc_Bal  All_Age_Mean_Acc_Bal  \
# 0             13.940808            14.492991             14.063587
# 1             13.738129            13.738129             13.738129
# 2             13.314880            14.569085             13.286757
# 3             13.644967            14.953412             13.469138
# 4             13.274235            14.595171             13.353236
#
#    All_Age_Max_Acc_Bal  All-Reg_Vin_Mean_Acc_Bal  All-Reg_Vin_Max_Acc_Bal  \
# 0            15.194791                 13.645882                16.012530
# 1            13.738129                 13.568729                13.866539
# 2            14.859411                 13.554347                15.946108
# 3            15.105414                 13.688854                15.959490
# 4            14.316171                 13.539512                16.046349
#
#    All-Reg_Age_Mean_Acc_Bal  All-Reg_Age_Max_Acc_Bal  \
# 0                 13.671345                15.194791
# 1                 13.738129                13.738129
# 2                 13.591043                15.449761
# 3                 13.650477                15.290126
# 4                 13.520901                15.057430
#
#    Gen-Occ-Ch-CP-Act_Mean_Acc_Bal  Gen-Occ-Ch-CP-Act_Max_Acc_Bal
# 0                       13.625126                      16.012530
# 1                       13.647208                      15.705779
# 2                       13.567591                      16.024404
# 3                       13.623680                      15.959490
# 4                       13.536073                      16.046349
#
# [5 rows x 32 columns]

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x='Kcluster', y='Avg_Account_Balance', hue='Is_Lead', data=df_train);
plt.figure(figsize=(12,5))
sns.countplot(x='Kcluster',hue='Is_Lead', data=df_train);

# %%
df_train.to_csv('train_clean_features.csv',index=False)
df_test.to_csv('test_clean_features.csv',index=False)
#test_submission.to_csv('submission_file_backup.csv',index=False)

# %% [markdown]
# ## Train-Test Split
#
# Split the data in Train-Test ration of 70:30, for both Linear model data and original data.

# %%
#df_train = pd.read_csv('train_clean_features.csv')
#df_test = pd.read_csv('test_clean_features.csv')
#test_submission = pd.read_csv('submission_file_backup.csv')

# %%
InteractiveShell.ast_node_interactivity = 'all'

# %%
X = df_train.drop(['Is_Lead'],axis=1)
y = df_train[['Is_Lead']]

X.head()
y.head()
# Out:
#    Gender  Age  Region_Code  Occupation  Channel_Code  Vintage  \
# 0       0   73           18           1             2       43
# 1       0   30           27           2             0       32
# 2       0   56           18           3             2       26
# 3       1   34           20           2             0       19
# 4       0   30           32           2             0       33
#
#    Credit_Product  Avg_Account_Balance  Is_Active  Kcluster  ...  \
# 0               0            13.860193          0        39  ...
# 1               0            13.274205          0        20  ...
# 2               0            14.210464          1         8  ...
# 3               0            13.061453          0        32  ...
# 4               0            13.695360          0        20  ...
#
#    All_Vin_Mean_Acc_Bal  All_Vin_Max_Acc_Bal  All_Age_Mean_Acc_Bal  \
# 0             13.860193            13.860193             14.043627
# 1             13.476343            15.029933             13.567265
# 2             14.210464            14.210464             14.438664
# 3             13.232258            14.513394             13.239825
# 4             13.580622            14.991054             13.649506
#
#    All_Age_Max_Acc_Bal  All-Reg_Vin_Mean_Acc_Bal  All-Reg_Vin_Max_Acc_Bal  \
# 0            14.892420                 13.671340                14.555509
# 1            15.379942                 13.640934                15.957762
# 2            14.666865                 14.210464                14.210464
# 3            14.460763                 13.554804                15.716717
# 4            14.912592                 13.685082                16.002864
#
#    All-Reg_Age_Mean_Acc_Bal  All-Reg_Age_Max_Acc_Bal  \
# 0                 13.986326                15.117223
# 1                 13.650102                15.803773
# 2                 13.968804                15.208201
# 3                 13.496126                15.716717
# 4                 13.650102                15.803773
#
#    Gen-Occ-Ch-CP-Act_Mean_Acc_Bal  Gen-Occ-Ch-CP-Act_Max_Acc_Bal
# 0                       13.916590                      15.762839
# 1                       13.640382                      16.002864
# 2                       13.871167                      15.314601
# 3                       13.567591                      16.024404
# 4                       13.640382                      16.002864
#
# [5 rows x 32 columns]
#   Is_Lead
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=51,stratify=df_train['Is_Lead'])


print(f'\033[1mSpliting the Company dataset in Ratio 75:25. \nShape of ---> \033[0m\n\033[34mX_Train:{X_train.shape}, \ny_train:{y_train.shape},\
      \nX_Test:{X_test.shape}, \ny_test:{y_test.shape}\033[0m')
# Out:
# Spliting the Company dataset in Ratio 75:25.
# Shape of --->
# X_Train:(172007, 32),
# y_train:(172007, 1),
# X_Test:(73718, 32),
# y_test:(73718, 1)

# %%
print(f"\n\033[7mProportion of Target class in original dataset:\033[0m\n{df_train.Is_Lead.value_counts(1)}")
print(f"\n\033[7mProportion of Target class post split in y_test:\033[0m\n{y_test.Is_Lead.value_counts(1)}")
# Out:
# Proportion of Target class in original dataset:
# 0    0.762792
# 1    0.237208
# Name: Is_Lead, dtype: float64
#
# Proportion of Target class post split in y_test:
# 0    0.762785
# 1    0.237215
# Name: Is_Lead, dtype: float64

# %% [markdown]
# ## Create SMOTE oversampled dataset - Skipping as it didn't improve Auc score.

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=1)

X_sm, y_sm = sm.fit_sample(X, y)  # to be used for full model
X_train_sm, y_train_sm = sm.fit_sample(X_train, y_train)  # to be used for model building
print(f"\n\033[7mShape of X_train_sm:\033[0m {X_train_sm.shape}")
print(f"\n\033[7mProportion of Target class post split in y_train_sm:\033[0m\n{y_train_sm.Is_Lead.value_counts(1)}")
# Out:
# Shape of X_train_sm: (262412, 17)
#
# Proportion of Target class post split in y_train_sm:
# 1    0.5
# 0    0.5
# Name: Is_Lead, dtype: float64

# %% [markdown]
# ## Create a Model Performance Log file to capture the Model performance output.

# %%
#Function to create a list of log from the existing model log excel file in working directory.
def create_perflog_list(perf_list, df):
    cols = df.columns
    for row in df.itertuples(index=False): 
        my_dict = {}
        for i, col in enumerate(cols):
            my_dict[col] = row[i]
        perf_list.append(my_dict)

    return perf_list

# Load the Model parameters and performance metrics log file from current working directory, if not present a new one will be created.
import os
from datetime import datetime
wd = os.getcwd()
filename = 'model_perf_log.xlsx'
fpath = wd + '\\' + filename #model log file name (which stores the model parameters and performance metrics)
perf_list = []   #create an empty list.
if os.path.isfile(fpath):
    print("Opening Model Log File at:\n\033[7m{}\033[0m".format(fpath))
    model_perf_log = pd.read_excel(filename)    #read existing log file into dataframe.
    perf_list = create_perflog_list(perf_list, model_perf_log)
else:
    print('The log file \033[7m{}\033[0m does not exist in current working directory. A new log file will be created.'.format(filename))
    print('Current working directory is:\n\033[7m{}\033[0m'.format(wd))
# Out:
# Opening Model Log File at:
# C:\Users\Abhin\Documents\GreatLearning\13. Hackathons\AnalyticsVidya\JOB-A-THON-May_2021\model_perf_log.xlsx

# %%
def capture_parameters(Model,Predict_On,model_score,AUC,Recall,Precision,F1_Score,best_grid,params,perf_list):
    grid_dict = {}
    grid_dict['Model'] = Model
    grid_dict['Predict_On'] = Predict_On
    grid_dict['Accuracy_Score'] = round(model_score,4)
    grid_dict['Precision'] = round(Precision,4)
    grid_dict['Recall'] = round(Recall,4)
    grid_dict['F1_Score'] = round(F1_Score,4)
    grid_dict['AUC'] = round(AUC,4)
    grid_dict['DateTimeStamp'] = str(datetime.now())
    grid_dict['Best_Parameters'] = str(params)
    grid_dict['Best_Grid'] = str(best_grid)
    
    perf_list.append(grid_dict)
    df = pd.DataFrame(perf_list)   
    return df, perf_list

def generate_model_performance(model_name,thres,predict_type,model,X,y,params,perf_list):
    # Generate the y predicted for Train and Test.
    ypred = model.predict(X)
    if 'SM_Logit' in model_name:
        ypred = sm_predict_y(model, thres, X)
    else:
        ypred = model.predict(X)

    print(f"\033[7m\nAccuracy score of {predict_type} Dataset:\033[0m")  # Accuracy Score
    train_acc = accuracy_score(y, ypred)
    print(f"Accuracy Score of {predict_type} Dataset is: {round(train_acc,4)*100} %")

    print(f"\033[7m\n\nClassification Report of {predict_type} Dataset:\033[0m")  # Classification Reports:
    train_precision, train_recall, train_f1 = classification(y, ypred)
    
    print(f"\033[7m\n\nConfusion Matrix of {predict_type} Dataset:\033[0m")  # Confusion Matrix
    confusion(y, ypred)
    
    print(f"\033[7m\n\nAUC ROC Curve of {predict_type} Dataset:\033[0m") # AUC Score
    train_auc = auc_roc(model_name,model,X,y)
    print(f"\033[7mArea Under the Curve for {predict_type} Dataset is: {round(train_auc,4)*100} %\033[0m\n")
      
    
    model_perf_log, perf_list = capture_parameters(model_name,predict_type,train_acc,train_auc,train_recall,
                                         train_precision,train_f1,model,params,perf_list)
    model_perf_log.to_excel('model_perf_log.xlsx', index=False)
    return model_perf_log, perf_list

def compare_model_performance(model_name,thres,model,X_train,y_train,X_test,y_test,params,perf_list):
    # Generate the y predicted for Train and Test.

    if 'SM_Logit' in model_name:
        ypred_train = sm_predict_y(model, thres, X_train)
        ypred_test = sm_predict_y(model, thres, X_test)
    else:
        ypred_train = model.predict(X_train)
        ypred_test = model.predict(X_test)

    print(f"\033[7m\nAccuracy scores:\033[0m")  # Accuracy Score
    train_acc = accuracy_score(y_train, ypred_train)
    test_acc = accuracy_score(y_test, ypred_test)
    print('Accuracy Score of Training Dataset:',round(train_acc,4)*100,'%')
    print('Accuracy Score of Testing Dataset:',round(test_acc,4)*100,'%')

#    print(f"\033[7m\n\nClassification Reports:\033[0m")  # Classification Reports:
    print(f"\033[7m\n\nClassification Report of Training Dataset:\033[0m")
    train_precision, train_recall, train_f1 = classification(y_train, ypred_train)
    print(f"\033[7m\nClassification Report of Testing Dataset:\033[0m")
    test_precision, test_recall, test_f1 = classification(y_test, ypred_test)
    
#    print(f"\033[7m\nConfusion Matrix Reports:\033[0m")  # Confusion Matrix
    print(f"\033[7m\n\nConfusion Matrix of Training Dataset:\033[0m")
    confusion(y_train, ypred_train)
    print(f"\033[7m\nConfusion Matrix of Testing Dataset:\033[0m")
    confusion(y_test, ypred_test)
    
    print(f"\033[7m\n\nAUC ROC Curve of Training Dataset:\033[0m") # AUC Score
    train_auc = auc_roc(model_name,model,X_train,y_train)
    print('\033[7mArea Under the Curve for Training Dataset',round(train_auc,4)*100,'%\033[0m\n')
    print(f"\033[7m\nAUC ROC Curve of Testing Dataset:\033[0m") # AUC Score
    test_auc = auc_roc(model_name,model,X_test,y_test)
    print('\033[7mArea Under the Curve for Testing Dataset',round(test_auc,4)*100,'%\033[0m\n')
      
   
    model_perf_log, perf_list = capture_parameters(model_name,'Training',train_acc,train_auc,train_recall,
                                         train_precision,train_f1,model,params,perf_list)
    model_perf_log, perf_list = capture_parameters(model_name,'Testing',test_acc,test_auc,test_recall,
                                         test_precision,test_f1,model,params,perf_list)
    model_perf_log.to_excel('model_perf_log.xlsx', index=False)
    return model_perf_log, perf_list

# %%
def classification(y,ypred):
    print(classification_report(y, ypred, target_names=['Non-Default', 'Default']))
    metrics=classification_report(y, ypred, output_dict=True)
    df=pd.DataFrame(metrics).transpose()
    precision=df.loc["1"][0]
    recall=df.loc["1"][1]
    f1=df.loc["1"][2]
    
    return precision, recall, f1

def confusion(y,ypred):
    cm = confusion_matrix(y,ypred)
    #print(cm)
    classNames = ['Non-Default', 'Default']
    cmlabel = np.array([['TN', 'FP'], ['FN','TP']])
    labels = (np.asarray(["{0} = {1:3d}".format(cmlabel, cmvalue)
                          for cmlabel, cmvalue in zip(cmlabel.flatten(), cm.ravel())])
             ).reshape(2, 2)
    #  'flatten' flattens the array and returns a copy, ravel returns a view of original array.
        #print(labels)
    sns.heatmap(cm, annot=labels, fmt='s', cbar=False,cmap='YlGnBu',
              xticklabels=classNames, yticklabels=classNames)
    plt.xlabel('Predicted Label')
    plt.ylabel('Actual Label')
    plt.title('Confusion Matrix')
    plt.yticks(rotation=0)
    plt.show()
    tn, fp, fn, tp = cm.ravel()
#    print('\nTN={}, FP={}, FN={}, TP={}'.format(tn, fp, fn, tp))
    print('\nActual Positives={}, Predicted Positives={}, Actual Negative={}, Predicted Negative={}'.format(
        (tp+fn),(tp+fp),(tn+fp),(tn+fn)))
    print('\nTotal number of observations = {}'.format(tn+fp+fn+tp))
    
def auc_roc(model_name,model,X,y):
    if 'SM_Logit' in model_name:
        ypred_prob = model.predict(X)    
    else:
        ypred_prob = model.predict_proba(X)[:,1]
        
    auc = roc_auc_score(y,ypred_prob)
    
    fpr, tpr,_=roc_curve(y,ypred_prob)
    plt.plot(fpr, tpr, marker='x', label='')
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC')
    plt.show()
    
    return auc

# Function to Predict y for Stats Model Logistic Regression prediction
def sm_predict_y(SM_model, thres, X):
    y_predict_prob = pd.DataFrame(SM_model.predict(X))
    y_class_pred= y_predict_prob.applymap(lambda x: 1 if x>thres else 0)
    return y_class_pred

# %% [markdown]
# ## Create a pipeline of base models and use Cross validation to check performance.

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import statsmodels.formula.api as sm
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from xgboost import XGBClassifier
import lightgbm as lgb
from sklearn import svm
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve,\
                            classification_report, confusion_matrix, plot_confusion_matrix

# %% [markdown]
# ### Model performance through pipeline Cross-validation using Original data.

# %%
from sklearn.pipeline import Pipeline
pipelines = []
pipelines.append(('Logistic Regression', Pipeline([('LR',LogisticRegression())])))
pipelines.append(('LDA', Pipeline([('LDA',LinearDiscriminantAnalysis())])))
#pipelines.append(('KNN Classifier', Pipeline([('KNN',KNeighborsClassifier())])))
#pipelines.append(('Naive Bayes', Pipeline([('NB',GaussianNB())])))
#pipelines.append(('Random Forest', Pipeline([('RF',RandomForestClassifier())])))
#pipelines.append(('GB Classifier', Pipeline([('GB',GradientBoostingClassifier())])))
#pipelines.append(('XGBoost Classifier', Pipeline([('XGB',XGBClassifier())])))
pipelines.append(('LightGBM Classifier', Pipeline([('LGBM',lgb.LGBMClassifier())])))
#pipelines.append(('ADABoost Classifier', Pipeline([('ADB',AdaBoostClassifier())])))
#pipelines.append(('Support Vector', Pipeline([('SVC',svm.SVC())])))

#pipelines.append(('ScaledGBM', Pipeline([('Scaler', MinMaxScaler()),('GBM', GradientBoostingRegressor())])))

results = []
names = []
for name, model in pipelines:
    cv_results = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')
#    cv_results = cross_val_score(model, X1_sm, y1_sm, cv=3, scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    msg = "\033[7m%20s:\033[0m \033[44mMean Score=%f\033[0m, \033[43mstd=%.4f\033[0m, \033[46mmax=%.4f\033[0m, \033[47mmin=%.4f\033[0m, \033[45mvar=%.4f\033[0m"\
    % (name, cv_results.mean(), cv_results.std(), cv_results.max(),cv_results.min(), (cv_results.max()-cv_results.min()))
    print(msg)
# Out:
#  Logistic Regression: Mean Score=0.850971, std=0.0013, max=0.8526, min=0.8493, var=0.0033
#                  LDA: Mean Score=0.853448, std=0.0020, max=0.8566, min=0.8511, var=0.0055
#  LightGBM Classifier: Mean Score=0.860157, std=0.0014, max=0.8626, min=0.8588, var=0.0039

# %%
results = []
names = []
for name, model in pipelines:
#    kfold = KFold(n_splits=10, random_state=101)
    cv_results = cross_val_score(model, X_train, y_train, cv=5, scoring='roc_auc')
    results.append(cv_results)
    names.append(name)
    msg = "\033[7m%20s:\033[0m \033[44mMean Score=%f\033[0m, \033[43mstd=%.4f\033[0m, \033[46mmax=%.4f\033[0m, \033[47mmin=%.4f\033[0m, \033[45mvar=%.4f\033[0m"\
    % (name, cv_results.mean(), cv_results.std(), cv_results.max(),cv_results.min(), (cv_results.max()-cv_results.min()))
    print(msg)
# Out:
#  Logistic Regression: Mean Score=0.856285, std=0.0035, max=0.8622, min=0.8523, var=0.0099
#                  LDA: Mean Score=0.858913, std=0.0033, max=0.8643, min=0.8552, var=0.0091
#  LightGBM Classifier: Mean Score=0.871831, std=0.0035, max=0.8774, min=0.8671, var=0.0103

# %%
results = []
names = []
for name, model in pipelines:
#    kfold = KFold(n_splits=10, random_state=101)
    cv_results = cross_val_score(model, X, y, cv=5, scoring='roc_auc')
    results.append(cv_results)
    names.append(name)
    msg = "\033[7m%20s:\033[0m \033[44mMean Score=%f\033[0m, \033[43mstd=%.4f\033[0m, \033[46mmax=%.4f\033[0m, \033[47mmin=%.4f\033[0m, \033[45mvar=%.4f\033[0m"\
    % (name, cv_results.mean(), cv_results.std(), cv_results.max(),cv_results.min(), (cv_results.max()-cv_results.min()))
    print(msg)
# Out:
#  Logistic Regression: Mean Score=0.856807, std=0.0008, max=0.8576, min=0.8554, var=0.0022
#                  LDA: Mean Score=0.859503, std=0.0008, max=0.8607, min=0.8583, var=0.0024
#  LightGBM Classifier: Mean Score=0.873436, std=0.0010, max=0.8749, min=0.8721, var=0.0029

# %% [markdown]
# ## Light-GBM Model

# %%
from sklearn.model_selection import GridSearchCV
import lightgbm as lgb
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

# %%
import lightgbm as lgb
model_LGBMcl = lgb.LGBMClassifier(boosting_type='gbdt',learning_rate=0.025,
                           n_estimators=10000,n_jobs=-1,max_depth=30, max_bin=100,
                            num_leaves=10, reg_alpha=8.457, reg_lambda=6.853, subsample=0.75, #min_child_samples=50,
                           random_state=1,silent=False,force_col_wise=True)

model_LGBMcl.fit(X_train, y_train, eval_set=[(X_test, y_test)], early_stopping_rounds=500,verbose=500)
# Out:
# [LightGBM] [Info] Number of positive: 40801, number of negative: 131206
# [LightGBM] [Info] Total Bins 2216
# [LightGBM] [Info] Number of data points in the train set: 172007, number of used features: 32
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.237205 -> initscore=-1.168062
# [LightGBM] [Info] Start training from score -1.168062
# Training until validation scores don't improve for 500 rounds
# [500]	valid_0's binary_logloss: 0.342432
# [1000]	valid_0's binary_logloss: 0.341887
# [1500]	valid_0's binary_logloss: 0.341869
# Early stopping, best iteration is:
# [1403]	valid_0's binary_logloss: 0.341853
# LGBMClassifier(force_col_wise=True, learning_rate=0.025, max_bin=100,
#                max_depth=30, n_estimators=10000, num_leaves=10, random_state=1,
#                reg_alpha=8.457, reg_lambda=6.853, silent=False, subsample=0.75)

# %%
LGBM_param = model_LGBMcl.get_params()
print(f"\033[7mBest Parameters of Light-GBM Model:\033[0m\n{LGBM_param}")
# Out:
# Best Parameters of Light-GBM Model:
# {'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.025, 'max_depth': 30, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 10000, 'n_jobs': -1, 'num_leaves': 10, 'objective': None, 'random_state': 1, 'reg_alpha': 8.457, 'reg_lambda': 6.853, 'silent': False, 'subsample': 0.75, 'subsample_for_bin': 200000, 'subsample_freq': 0, 'max_bin': 100, 'force_col_wise': True}

# %%
print(f"\033[7m\nAccuracy scores:\033[0m") 
print('Base score of Light-GBM Model on Training Dataset:', model_LGBMcl.score(X_train, y_train).round(3))
print('Base score of Light-GBM Model on Testing Dataset:', model_LGBMcl.score(X_test, y_test).round(3))
# Out:
# Accuracy scores:
# Base score of Light-GBM Model on Training Dataset: 0.864
# Base score of Light-GBM Model on Testing Dataset: 0.861

# %%
x=pd.DataFrame(model_LGBMcl.feature_importances_,index=X_test.columns).sort_values(by=0,ascending=False)
plt.figure(figsize=(12,8))
sns.barplot(x[0],x.index,palette='rainbow')
plt.ylabel('Feature Name')
plt.xlabel('Feature Importance value')
plt.title('Feature Importance Plot')
plt.show();

# %%
model_perf_log, perf_list = compare_model_performance('LightGBM',0.5,model_LGBMcl,X_train, y_train,X_test,y_test,LGBM_param,perf_list)
# Out:
# Accuracy scores:
# Accuracy Score of Training Dataset: 86.38 %
# Accuracy Score of Testing Dataset: 86.14 %
#
#
# Classification Report of Training Dataset:
#               precision    recall  f1-score   support
#
#  Non-Default       0.87      0.96      0.91    131206
#      Default       0.81      0.55      0.66     40801
#
#     accuracy                           0.86    172007
#    macro avg       0.84      0.76      0.79    172007
# weighted avg       0.86      0.86      0.85    172007
#
#
# Classification Report of Testing Dataset:
#               precision    recall  f1-score   support
#
#  Non-Default       0.87      0.96      0.91     56231
#      Default       0.81      0.55      0.65     17487
#
#     accuracy                           0.86     73718
#    macro avg       0.84      0.75      0.78     73718
# weighted avg       0.86      0.86      0.85     73718
#
#
#
# Confusion Matrix of Training Dataset:
# Actual Positives=40801, Predicted Positives=27635, Actual Negative=131206, Predicted Negative=144372
#
# Total number of observations = 172007
#
# Confusion Matrix of Testing Dataset:
# Actual Positives=17487, Predicted Positives=11816, Actual Negative=56231, Predicted Negative=61902
#
# Total number of observations = 73718
#
#
# AUC ROC Curve of Training Dataset:
# Area Under the Curve for Training Dataset 88.19 %
#
#
# AUC ROC Curve of Testing Dataset:
# Area Under the Curve for Testing Dataset 87.53 %

# %% [markdown]
# ## Drop some Not useful features

# %%
features_keep = ['Age', 'Region_Code', 'Occupation', 'Channel_Code', 'Vintage',
       'Credit_Product', 'Avg_Account_Balance', 'Kcluster',
       'All_Vin_Max_Acc_Bal', 
       'All_Age_Max_Acc_Bal', 'All-Reg_Vin_Mean_Acc_Bal', 
       'All-Reg_Age_Max_Acc_Bal', 
       'Gen-Occ-Ch-CP-Act_Max_Acc_Bal']

# %%
X1 = X[features_keep].copy()
df_test1 = df_test[features_keep].copy()

# %%
X1.columns
df_test1.columns
# Out:
# Index(['Age', 'Region_Code', 'Occupation', 'Channel_Code', 'Vintage',
#        'Avg_Account_Balance', 'Kcluster', 'All_Vin_Max_Acc_Bal',
#        'All-Reg_Age_Max_Acc_Bal', 'Gen-Occ-Ch-CP-Act_Max_Acc_Bal'],
#       dtype='object')
# Index(['Age', 'Region_Code', 'Occupation', 'Channel_Code', 'Vintage',
#        'Avg_Account_Balance', 'Kcluster', 'All_Vin_Max_Acc_Bal',
#        'All-Reg_Age_Max_Acc_Bal', 'Gen-Occ-Ch-CP-Act_Max_Acc_Bal'],
#       dtype='object')

# %% [markdown]
# ## LGBM Model with Pipeline Cross validation

# %%
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import roc_auc_score

def cross_val(X, y, model, params, folds=9):

    skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=21)
    for fold, (train_idx, test_idx) in enumerate(skf.split(X, y)):
        print(f"Fold: {fold}")
        x_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
        x_test, y_test = X.iloc[test_idx], y.iloc[test_idx]

        alg = model(**params)
        alg.fit(x_train, y_train,
                eval_set=[(x_test, y_test)],
                early_stopping_rounds=100,
                verbose=400)

        pred = alg.predict_proba(x_test)[:, 1]
        roc_score = roc_auc_score(y_test, pred)
        print(f"roc_auc_score: {roc_score}")
        print("-"*50)
    
    return alg

# %%
lgb_params= {'learning_rate': 0.025, 
             'n_estimators': 10000, 
             'max_bin': 100,
             'num_leaves': 10, 
             'max_depth': 30, 
             'reg_alpha': 8.457, 
             'reg_lambda': 6.853, 
             'subsample': 0.75,
            }

# %%
from lightgbm import LGBMClassifier
lgb_model = cross_val(X, y, LGBMClassifier, lgb_params)
# Out:
# Fold: 0
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.341992
# Early stopping, best iteration is:
# [607]	valid_0's binary_logloss: 0.341794
# roc_auc_score: 0.8761892732129295
# --------------------------------------------------
# Fold: 1
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.348809
# [800]	valid_0's binary_logloss: 0.348528
# Early stopping, best iteration is:
# [752]	valid_0's binary_logloss: 0.348501
# roc_auc_score: 0.8714258597244815
# --------------------------------------------------
# Fold: 2
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.346894
# [800]	valid_0's binary_logloss: 0.34654
# Early stopping, best iteration is:
# [1047]	valid_0's binary_logloss: 0.34648
# roc_auc_score: 0.8710900504117673
# --------------------------------------------------
# Fold: 3
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.347457
# [800]	valid_0's binary_logloss: 0.346965
# Early stopping, best iteration is:
# [849]	valid_0's binary_logloss: 0.346945
# roc_auc_score: 0.8710799707750022
# --------------------------------------------------
# Fold: 4
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.343009
# Early stopping, best iteration is:
# [691]	valid_0's binary_logloss: 0.342587
# roc_auc_score: 0.875188655568409
# --------------------------------------------------
# Fold: 5
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.345717
# [800]	valid_0's binary_logloss: 0.345297
# [1200]	valid_0's binary_logloss: 0.345221
# Early stopping, best iteration is:
# [1186]	valid_0's binary_logloss: 0.345211
# roc_auc_score: 0.8722461950886473
# --------------------------------------------------
# Fold: 6
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.340448
# [800]	valid_0's binary_logloss: 0.339811
# Early stopping, best iteration is:
# [977]	valid_0's binary_logloss: 0.339702
# roc_auc_score: 0.8777723941319238
# --------------------------------------------------
# Fold: 7
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.343167
# [800]	valid_0's binary_logloss: 0.342725
# Early stopping, best iteration is:
# [920]	valid_0's binary_logloss: 0.342681
# roc_auc_score: 0.8763759556149435
# --------------------------------------------------
# Fold: 8
# Training until validation scores don't improve for 100 rounds
# [400]	valid_0's binary_logloss: 0.345751
# [800]	valid_0's binary_logloss: 0.345374
# Early stopping, best iteration is:
# [851]	valid_0's binary_logloss: 0.345329
# roc_auc_score: 0.8702551092919854
# --------------------------------------------------

# %%
x=pd.DataFrame(lgb_model.feature_importances_,index=X.columns).sort_values(by=0,ascending=False)
plt.figure(figsize=(12,10))
sns.barplot(x[0],x.index,palette='rainbow')
plt.ylabel('Feature Name')
plt.xlabel('Feature Importance value')
plt.title('Feature Importance Plot')
plt.show();

# %% [markdown]
# ## Generate submission file.

# %% [markdown]
# ### Fit model on full Train data and generate submission file.

# %%
model = model_LGBMcl  # lgb_model, model_LGBMcl

# %%
model.fit(X, y)
ypred_lgb = model.predict_proba(df_test)[:,1]
test_submission['Is_Lead'] = ypred_lgb
test_submission.head()
# Out:
# [LightGBM] [Info] Number of positive: 58288, number of negative: 187437
# [LightGBM] [Info] Total Bins 2216
# [LightGBM] [Info] Number of data points in the train set: 245725, number of used features: 32
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.237208 -> initscore=-1.168047
# [LightGBM] [Info] Start training from score -1.168047
# LGBMClassifier(force_col_wise=True, learning_rate=0.025, max_bin=100,
#                max_depth=30, n_estimators=10000, num_leaves=10, random_state=1,
#                reg_alpha=8.457, reg_lambda=6.853, silent=False, subsample=0.75)
#          ID   Is_Lead
# 0  VBENBARO  0.039066
# 1  CCMEWNKY  0.897619
# 2  VK3KGA9M  0.050174
# 3  TT8RPZVC  0.029427
# 4  SHQZEYTZ  0.017929

# %%
test_submission.to_csv('Submission_File_LGBM_20_Clust_6.csv',index=False)
